# %%
from warnings import filterwarnings

filterwarnings("ignore")

import pandas as pd
import numpy as np

from statsmodels.tsa.stattools import grangercausalitytests
import matplotlib.pyplot as plt
from itertools import permutations
from tqdm import tqdm

from quant_invest_lab.utils import get_cac40_symbols
from quant_invest_lab.data_provider import build_multi_crypto_dataframe, download_crypto_historical_data

# %%
MININUM_HISTORY_YEAR = 1
N = 365
# get_list_of_symbols()
symbols = set(
    [
        "OAS-USDT", "NEO-BTC", "KNC-USDT", "LYM-USDT", "NIM-ETH",
        "TON-USDT", "CFX-ETH", "WAX-BTC", "DOGE-USDC", "CWAR-USDT", "ICPUP-USDT", "AAVE-USDT", "EWT-KCS",
        "ROSE-USDT",
        "AVAX-USDT",
        "UNI-USDT",
        "ATOM-USDT",
        "ICP-USDT",
        "THETA-USDT",
        "VET-USDT",
        "DOGE3S-USDT",
        "BNB-USDT",
        "NEAR-BTC",
        "BTC-USDT",
        "NEAR-USDT",
        "SOLVE-BTC",
        "ETH-USDT",
        "KDA-USDT",
        "SOL-USDT",
        "EGLD-USDT",
        "ALGO-USDT",
        "FTM-USDT",
        "AXS-USDT",
        "ADA-USDT",
        "NKN-USDT",
        "LOOM-BTC",
        "CUSD-USDT",
        "LTC3L-USDT",
        "XPR-USDT",
    ]
)


closes = build_multi_crypto_dataframe(symbols)

cols_to_remove = [
    col
    for col, nans in closes.isna().sum().items()
    if len(closes) - nans < int(N * MININUM_HISTORY_YEAR)
]


closes.drop(columns=cols_to_remove, inplace=True)
returns = closes.pct_change().dropna()
log_returns = np.log(closes).pct_change().dropna()
returns.head()
# Out:
#             LOOM-BTC_Close  ROSE-USDT_Close  VET-USDT_Close  AVAX-USDT_Close  \
# Date
# 2021-03-18        0.210909        -0.113455        0.011595         0.015400
# 2021-03-19       -0.063063        -0.035220        0.043658         0.123951
# 2021-03-20       -0.019231        -0.002097        0.105900        -0.084177
# 2021-03-21        0.006536         0.167348        0.046807        -0.042039
# 2021-03-22        0.061688        -0.136010       -0.057433        -0.107483
#
#             SOLVE-BTC_Close  UNI-USDT_Close  ALGO-USDT_Close  \
# Date
# 2021-03-18         0.285714       -0.041741        -0.024277
# 2021-03-19         0.000000        0.110345        -0.007790
# 2021-03-20        -0.146538       -0.039371        -0.032927
# 2021-03-21         0.056604        0.026449        -0.021953
# 2021-03-22        -0.028571       -0.000113        -0.066576
#
#             THETA-USDT_Close  ETH-USDT_Close  ATOM-USDT_Close  FTM-USDT_Close  \
# Date
# 2021-03-18          0.071096       -0.025642         0.056637       -0.066114
# 2021-03-19         -0.022681        0.018789         0.005138        0.039372
# 2021-03-20          0.012084       -0.001780        -0.059096        0.030256
# 2021-03-21          0.151563       -0.012690        -0.018490       -0.000211
# 2021-03-22          0.044366       -0.057339        -0.065317       -0.074746
#
#             ADA-USDT_Close  BTC-USDT_Close  BNB-USDT_Close
# Date
# 2021-03-18       -0.110428       -0.020839       -0.031226
# 2021-03-19        0.053323        0.006510        0.006515
# 2021-03-20       -0.072942        0.001539        0.004986
# 2021-03-21       -0.011763       -0.013135        0.001433
# 2021-03-22       -0.071503       -0.056741       -0.036593

# %%
closes = closes.dropna()
closes_standard = (closes - closes.mean()) / closes.std()


def get_max_pvalue(
    timeseries: pd.DataFrame, perm: list[str], max_lag: int = 10
) -> tuple[str, float, int]:
    """Return the max p-value and lag for a given timeseries permutation of 2 with the Granger Causality Test

    Args:
        timeseries (pd.DataFrame): The timeseries at least 2 columns.
        perm (list[str]): The permutation of 2 columns to test.
        max_lag (int): The max lag to test. Defaults to 10.

    Returns:
        tuple[str, float, int]: The permutation tested, the max p-value and the lag.
    """
    assert len(perm) == 2, "Only 2 columns timeseries are supported"
    assert all([col in timeseries.columns for col in perm]), "Columns not in timeseries"
    assert max_lag > 0 and max_lag < len(
        timeseries
    ), "max_lag must be greater than 0 and less than the timeseries length"

    gct_res = grangercausalitytests(timeseries[perm], max_lag, verbose=False)
    return ",".join(perm), *min(
        [(v[0]["ssr_ftest"][1], v[0]["ssr_ftest"][-1]) for v in gct_res.values()],
        key=lambda val: val[0],
    )


p_vals = []
for perm in tqdm(map(list, permutations(closes_standard.columns.tolist(), 2))):
    p_vals.append(get_max_pvalue(closes_standard, perm, 20))


p_vals_filtered = filter(lambda x: x[1] < 0.05, p_vals)
p_vals_filtered_high_lags = filter(lambda x: x[-1] >= 2, p_vals_filtered)
sorted_p_vals = sorted(p_vals_filtered_high_lags, key=lambda x: x[1], reverse=True)

sorted_p_vals
# Out:
# 182it [02:37,  1.16it/s]
# [('LOOM-BTC_Close,THETA-USDT_Close', 0.04828110402928003, 16),
#  ('ALGO-USDT_Close,LOOM-BTC_Close', 0.047886884841091104, 4),
#  ('THETA-USDT_Close,AVAX-USDT_Close', 0.04725658826275443, 11),
#  ('AVAX-USDT_Close,UNI-USDT_Close', 0.045776620889966306, 5),
#  ('FTM-USDT_Close,THETA-USDT_Close', 0.04558798614084004, 15),
#  ('ETH-USDT_Close,BNB-USDT_Close', 0.04229745480322453, 13),
#  ('ROSE-USDT_Close,ADA-USDT_Close', 0.04153009722587432, 10),
#  ('BTC-USDT_Close,ADA-USDT_Close', 0.04131019429004342, 7),
#  ('ATOM-USDT_Close,SOLVE-BTC_Close', 0.038290381726750825, 13),
#  ('BTC-USDT_Close,LOOM-BTC_Close', 0.03434807848460262, 17),
#  ('ADA-USDT_Close,LOOM-BTC_Close', 0.033937656972443275, 4),
#  ('LOOM-BTC_Close,BTC-USDT_Close', 0.03372394635860658, 6),
#  ('BTC-USDT_Close,SOLVE-BTC_Close', 0.03294269425856433, 19),
#  ('LOOM-BTC_Close,AVAX-USDT_Close', 0.03256285867605351, 2),
#  ('BTC-USDT_Close,AVAX-USDT_Close', 0.03220351055950523, 18),
#  ('UNI-USDT_Close,LOOM-BTC_Close', 0.030327452171089418, 15),
#  ('BTC-USDT_Close,UNI-USDT_Close', 0.027606185382510792, 18),
#  ('ATOM-USDT_Close,THETA-USDT_Close', 0.027374112527339362, 15),
#  ('ADA-USDT_Close,SOLVE-BTC_Close', 0.02657548603757335, 10),
#  ('FTM-USDT_Close,BTC-USDT_Close', 0.024149305232703557, 13),
#  ('LOOM-BTC_Close,ADA-USDT_Close', 0.022705582020135992, 2),
#  ('VET-USDT_Close,LOOM-BTC_Close', 0.022682039779605385, 14),
#  ('BTC-USDT_Close,ROSE-USDT_Close', 0.018882568455024996, 14),
#  ('THETA-USDT_Close,ALGO-USDT_Close', 0.017207203127229342, 20),
#  ('THETA-USDT_Close,LOOM-BTC_Close', 0.017203684126004433, 13),
#  ('ROSE-USDT_Close,ATOM-USDT_Close', 0.017016702806743698, 6),
#  ('ADA-USDT_Close,ROSE-USDT_Close', 0.016716502325225032, 14),
#  ('AVAX-USDT_Close,BNB-USDT_Close', 0.015994631398951867, 6),
#  ('AVAX-USDT_Close,VET-USDT_Close', 0.013703587794556774, 4),
#  ('ATOM-USDT_Close,VET-USDT_Close', 0.013070491483536078, 8),
#  ('ADA-USDT_Close,BTC-USDT_Close', 0.012950585668832863, 14),
#  ('SOLVE-BTC_Close,FTM-USDT_Close', 0.01178609686317701, 17),
#  ('FTM-USDT_Close,ATOM-USDT_Close', 0.011676398679017676, 2),
#  ('AVAX-USDT_Close,BTC-USDT_Close', 0.010047011199987093, 18),
#  ('ALGO-USDT_Close,BTC-USDT_Close', 0.010040445949032861, 2),
#  ('SOLVE-BTC_Close,ADA-USDT_Close', 0.009583081061662498, 10),
#  ('ETH-USDT_Close,LOOM-BTC_Close', 0.009126770481737717, 2),
#  ('SOLVE-BTC_Close,ETH-USDT_Close', 0.00906254960919335, 17),
#  ('FTM-USDT_Close,ETH-USDT_Close', 0.007555771084581845, 14),
#  ('ETH-USDT_Close,ATOM-USDT_Close', 0.006479274191504291, 11),
#  ('SOLVE-BTC_Close,VET-USDT_Close', 0.0061964797302989354, 17),
#  ('VET-USDT_Close,FTM-USDT_Close', 0.006002341528881666, 11),
#  ('ATOM-USDT_Close,BTC-USDT_Close', 0.005961601283459745, 2),
#  ('ETH-USDT_Close,AVAX-USDT_Close', 0.005789103107365848, 17),
#  ('LOOM-BTC_Close,ETH-USDT_Close', 0.0053309861186719735, 3),
#  ('BTC-USDT_Close,ALGO-USDT_Close', 0.005169330037143594, 13),
#  ('ADA-USDT_Close,ATOM-USDT_Close', 0.00419101712860013, 14),
#  ('ATOM-USDT_Close,BNB-USDT_Close', 0.0037843069565542627, 14),
#  ('THETA-USDT_Close,ATOM-USDT_Close', 0.0036754543669694152, 9),
#  ('BNB-USDT_Close,ATOM-USDT_Close', 0.003588985194328468, 2),
#  ('ADA-USDT_Close,AVAX-USDT_Close', 0.003446203553624026, 18),
#  ('VET-USDT_Close,ADA-USDT_Close', 0.0026499846365878755, 8),
#  ('THETA-USDT_Close,FTM-USDT_Close', 0.002430309518852204, 11),
#  ('ROSE-USDT_Close,BTC-USDT_Close', 0.0018961410379047864, 15),
#  ('UNI-USDT_Close,AVAX-USDT_Close', 0.0013004560974390603, 16),
#  ('BNB-USDT_Close,LOOM-BTC_Close', 0.001133323543149499, 2),
#  ('AVAX-USDT_Close,ETH-USDT_Close', 0.0008815672314130299, 19),
#  ('ALGO-USDT_Close,ETH-USDT_Close', 0.0008524819241497478, 9),
#  ('SOLVE-BTC_Close,UNI-USDT_Close', 0.0006186012860033812, 19),
#  ('AVAX-USDT_Close,THETA-USDT_Close', 0.000587416035386126, 19),
#  ('BNB-USDT_Close,SOLVE-BTC_Close', 0.0005090415547349953, 11),
#  ('BNB-USDT_Close,UNI-USDT_Close', 0.00045072889989842754, 9),
#  ('BNB-USDT_Close,ALGO-USDT_Close', 0.0004229887623583331, 9),
#  ('ADA-USDT_Close,UNI-USDT_Close', 0.00038207485042689756, 19),
#  ('AVAX-USDT_Close,ADA-USDT_Close', 0.00034707723727786223, 4),
#  ('BNB-USDT_Close,FTM-USDT_Close', 0.0003390572772399678, 19),
#  ('BTC-USDT_Close,ATOM-USDT_Close', 0.0003104557749577912, 6),
#  ('UNI-USDT_Close,ROSE-USDT_Close', 0.00030934770395978886, 19),
#  ('THETA-USDT_Close,SOLVE-BTC_Close', 0.0002909576536056721, 19),
#  ('ETH-USDT_Close,VET-USDT_Close', 0.00026502388903154735, 20),
#  ('AVAX-USDT_Close,FTM-USDT_Close', 0.00024541110994466444, 7),
#  ('ALGO-USDT_Close,THETA-USDT_Close', 0.0002290074376577154, 6),
#  ('FTM-USDT_Close,SOLVE-BTC_Close', 0.0002002690779906249, 19),
#  ('ALGO-USDT_Close,FTM-USDT_Close', 0.00019468147383677685, 13),
#  ('UNI-USDT_Close,BTC-USDT_Close', 0.00015151378144288692, 18),
#  ('SOLVE-BTC_Close,ALGO-USDT_Close', 0.00013939086796655226, 10),
#  ('BTC-USDT_Close,VET-USDT_Close', 0.00010290132286595649, 6),
#  ('FTM-USDT_Close,AVAX-USDT_Close', 9.908009765541708e-05, 20),
#  ('ADA-USDT_Close,FTM-USDT_Close', 8.71266813165202e-05, 11),
#  ('VET-USDT_Close,ALGO-USDT_Close', 7.858611593656415e-05, 8),
#  ('FTM-USDT_Close,ROSE-USDT_Close', 7.685829918804522e-05, 20),
#  ('UNI-USDT_Close,FTM-USDT_Close', 5.2924092471342626e-05, 12),
#  ('ALGO-USDT_Close,AVAX-USDT_Close', 4.833101255998468e-05, 17),
#  ('BNB-USDT_Close,ADA-USDT_Close', 4.214289889647702e-05, 9),
#  ('ALGO-USDT_Close,BNB-USDT_Close', 3.922867813502397e-05, 18),
#  ('VET-USDT_Close,SOLVE-BTC_Close', 3.723683483166842e-05, 19),
#  ('AVAX-USDT_Close,ATOM-USDT_Close', 3.280059747465733e-05, 4),
#  ('ETH-USDT_Close,ALGO-USDT_Close', 2.8719580652229326e-05, 16),
#  ('AVAX-USDT_Close,ALGO-USDT_Close', 2.7250281252618595e-05, 14),
#  ('ETH-USDT_Close,THETA-USDT_Close', 2.237239290167714e-05, 16),
#  ('ROSE-USDT_Close,FTM-USDT_Close', 2.2193117902477e-05, 13),
#  ('ALGO-USDT_Close,ROSE-USDT_Close', 1.72772012637821e-05, 15),
#  ('ETH-USDT_Close,UNI-USDT_Close', 1.388324675043056e-05, 20),
#  ('SOLVE-BTC_Close,BTC-USDT_Close', 1.1094105718956063e-05, 10),
#  ('ADA-USDT_Close,VET-USDT_Close', 9.618350665138323e-06, 8),
#  ('ATOM-USDT_Close,FTM-USDT_Close', 8.907732293031828e-06, 12),
#  ('ETH-USDT_Close,ADA-USDT_Close', 8.612588073650424e-06, 8),
#  ('BTC-USDT_Close,ETH-USDT_Close', 8.036399000232418e-06, 8),
#  ('ATOM-USDT_Close,AVAX-USDT_Close', 6.555002558943912e-06, 19),
#  ('ALGO-USDT_Close,VET-USDT_Close', 5.345007009908198e-06, 8),
#  ('ADA-USDT_Close,ETH-USDT_Close', 4.306649808075846e-06, 12),
#  ('BNB-USDT_Close,VET-USDT_Close', 3.04674714417528e-06, 10),
#  ('FTM-USDT_Close,ALGO-USDT_Close', 2.6256215602441163e-06, 13),
#  ('ADA-USDT_Close,THETA-USDT_Close', 2.1933716813689867e-06, 3),
#  ('ROSE-USDT_Close,ALGO-USDT_Close', 1.7385908015540724e-06, 15),
#  ('THETA-USDT_Close,BTC-USDT_Close', 1.7220018284534422e-06, 20),
#  ('ADA-USDT_Close,ALGO-USDT_Close', 1.6243611622283768e-06, 7),
#  ('THETA-USDT_Close,ADA-USDT_Close', 1.4000239458059837e-06, 10),
#  ('ADA-USDT_Close,BNB-USDT_Close', 8.991661764440642e-07, 7),
#  ('AVAX-USDT_Close,ROSE-USDT_Close', 8.502048383591045e-07, 9),
#  ('THETA-USDT_Close,ETH-USDT_Close', 7.333274844058369e-07, 20),
#  ('ALGO-USDT_Close,UNI-USDT_Close', 7.107899935530007e-07, 17),
#  ('ALGO-USDT_Close,ATOM-USDT_Close', 6.923052726812228e-07, 2),
#  ('ROSE-USDT_Close,AVAX-USDT_Close', 6.337888414659732e-07, 16),
#  ('ATOM-USDT_Close,ROSE-USDT_Close', 6.252447670282508e-07, 15),
#  ('UNI-USDT_Close,THETA-USDT_Close', 5.164135668983068e-07, 20),
#  ('BTC-USDT_Close,THETA-USDT_Close', 3.4903817166266346e-07, 14),
#  ('ATOM-USDT_Close,ADA-USDT_Close', 2.3273483015384868e-07, 7),
#  ('BTC-USDT_Close,BNB-USDT_Close', 2.1295037976467952e-07, 9),
#  ('ETH-USDT_Close,FTM-USDT_Close', 1.9488018197657526e-07, 12),
#  ('BTC-USDT_Close,FTM-USDT_Close', 4.619085103435486e-08, 13),
#  ('UNI-USDT_Close,ADA-USDT_Close', 4.5949471899312275e-08, 18),
#  ('THETA-USDT_Close,VET-USDT_Close', 3.444917841689293e-08, 10),
#  ('UNI-USDT_Close,ETH-USDT_Close', 1.67306540748409e-08, 18),
#  ('ALGO-USDT_Close,ADA-USDT_Close', 8.294641191915534e-09, 20),
#  ('THETA-USDT_Close,UNI-USDT_Close', 7.0920021221564965e-09, 18),
#  ('UNI-USDT_Close,BNB-USDT_Close', 6.914068885605923e-09, 18),
#  ('UNI-USDT_Close,VET-USDT_Close', 3.686221028068519e-09, 18),
#  ('VET-USDT_Close,ETH-USDT_Close', 2.2619498798358236e-09, 10),
#  ('BNB-USDT_Close,BTC-USDT_Close', 7.993961598731147e-10, 9),
#  ('UNI-USDT_Close,ALGO-USDT_Close', 3.5153226519126585e-10, 18),
#  ('ETH-USDT_Close,BTC-USDT_Close', 3.329388869790466e-10, 13),
#  ('VET-USDT_Close,BTC-USDT_Close', 2.2620076487335968e-10, 7),
#  ('THETA-USDT_Close,BNB-USDT_Close', 1.170306445446598e-10, 16),
#  ('SOLVE-BTC_Close,THETA-USDT_Close', 4.2071823844779406e-11, 17),
#  ('VET-USDT_Close,THETA-USDT_Close', 1.581551170999846e-11, 20),
#  ('VET-USDT_Close,BNB-USDT_Close', 8.253060421046693e-12, 16),
#  ('ATOM-USDT_Close,ALGO-USDT_Close', 3.2686156632653474e-12, 20),
#  ('BNB-USDT_Close,THETA-USDT_Close', 1.1563451954694636e-12, 9),
#  ('VET-USDT_Close,UNI-USDT_Close', 8.653191185789017e-15, 20)]
